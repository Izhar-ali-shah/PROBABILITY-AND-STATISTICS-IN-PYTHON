# %%
import pandas as pd

# %%
url = "data/b.csv"
da = pd.read_csv(url)

# %%
da
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 0         Exports  2015  01/01/2015   Thursday     All       All
# 1         Exports  2015  02/01/2015     Friday     All       All
# 2         Exports  2015  03/01/2015   Saturday     All       All
# 3         Exports  2015  04/01/2015     Sunday     All       All
# 4         Exports  2015  05/01/2015     Monday     All       All
# ...           ...   ...         ...        ...     ...       ...
# 104968  Reimports  2021  17/07/2021   Saturday     All       All
# 104969  Reimports  2021  18/07/2021     Sunday     All       All
# 104970  Reimports  2021  19/07/2021     Monday     All       All
# 104971  Reimports  2021  20/07/2021    Tuesday     All       All
# 104972  Reimports  2021  21/07/2021  Wednesday     All       All
#
#        Transport_Mode Measure      Value  Cumulative
# 0                 All       $  104000000   104000000
# 1                 All       $   96000000   200000000
# ...

# %%
da['Value']
# Out:
# 0         104000000
# 1          96000000
# 2          61000000
# 3          74000000
# 4         105000000
#             ...
# 104968            0
# 104969            0
# 104970            0
# 104971      1000000
# 104972            0
# Name: Value, Length: 104973, dtype: int64

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(20,5))
x = range(da['Value'].size)
y = da['Value']

plt.scatter(x, y, marker='x', s=0.1)
plt.title("Amount Spent ")
plt.xlabel("no of export+reimports")
plt.ylabel("Money $")

plt.show()

# %%
sum(y)
# Out:
# 3007993715000

# %%
len(y)
# Out:
# 104973

# %%
sum(y)/len(y)
# Out:
# 28654927.600430585

# %%
y = y.dropna()
